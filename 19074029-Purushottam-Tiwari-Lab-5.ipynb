# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "gdrive/My Drive"
# Out:
# /content/gdrive/My Drive

# %%
# !pwd
# Out:
# /content/gdrive/My Drive

# %%
# !git clone https://github.com/srvCodes/morph_analyzer.git
# Out:
# Cloning into 'morph_analyzer'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 516 (delta 42), reused 33 (delta 33), pack-reused 471
# Receiving objects: 100% (516/516), 28.97 MiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %%
# %cd morph_analyzer/
# Out:
# /content/gdrive/My Drive/morph_analyzer

# %%
# !pip3 install funcsigs

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip -P "/content/gdrive/My Drive/"
# Out:
# --2021-03-20 09:19:56--  http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip [following]
# --2021-03-20 09:19:56--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628493531 (599M) [application/zip]
# Saving to: ‘/content/gdrive/My Drive/HDTB_pre_release_version-0.05.zip’
#
# HDTB_pre_release_ve 100%[===================>] 599.38M  3.69MB/s    in 2m 28s
#
# ...

# %%
# !rm -rf "src/HDTB_pre_release_version-0.05"

# %%
# !unzip "/content/gdrive/My Drive/HDTB_pre_release_version-0.05.zip" -d src/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494108_date_1_6_2004.dat
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494312_date_1_6_2004.dat
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2571134_date_4_7_2004.dat
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2561717_date_30_6_2004.dat
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2501730_date_4_6_2004.dat
#   inflating: src/HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2506457_date_6_6_2004.dat
# ...

# %%
# !python3 main.py --lang hindi --mode train --phonetic true --freezing true
# Out:
# 2021-03-20 10:16:23.848943: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# tcmalloc: large alloc 4456816640 bytes == 0x564a41f98000 @  0x7fa4f5b61001 0x7fa4f35df54f 0x7fa4f362fb58 0x7fa4f3633b17 0x7fa4f36d2203 0x564a1f911050 0x564a1f910de0 0x564a1f985244 0x564a1f91269a 0x564a1f984e50 0x564a1f91269a 0x564a1f980c9e 0x564a1f97fe0d 0x564a1f91277a 0x564a1f980a45 0x564a1f97fb0e 0x564a1f97f813 0x564a1fa49592 0x564a1fa4990d 0x564a1fa497b6 0x564a1fa21103 0x564a1fa20dac 0x7fa4f4949bf7 0x564a1fa20c8a
# 2021-03-20 10:17:45.534380: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 10:17:45.535374: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python3 main.py --lang hindi --mode test --phonetic true --freezing false
# Out:
# 2021-03-20 10:30:40.044985: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-20 10:30:50.880384: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 10:30:50.887579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 10:30:50.919205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-20 10:30:50.919798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !python3 main.py --lang hindi --mode predict --phonetic true --freezing false
# Out:
# 2021-03-20 10:32:57.264495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-20 10:32:59.771065: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 10:32:59.771933: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 10:32:59.802260: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-20 10:32:59.802855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip -P "/content/gdrive/My Drive/"
# Out:
# --2021-03-20 10:58:22--  http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip [following]
# --2021-03-20 10:58:23--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226297009 (216M) [application/zip]
# Saving to: ‘/content/gdrive/My Drive/UDTB_pre_release_version-0.01.zip’
#
# UDTB_pre_release_ve 100%[===================>] 215.81M  7.26MB/s    in 41s
#
# ...

# %%
# !unzip "/content/gdrive/My Drive/UDTB_pre_release_version-0.01.zip" -d src/
# Out:
# Archive:  /content/gdrive/My Drive/UDTB_pre_release_version-0.01.zip
#    creating: src/UDTB_pre_release_version-0.01/
#    creating: src/UDTB_pre_release_version-0.01/Inter-chunk/
#    creating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/
#    creating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/
#    creating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/
#    creating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/
#   inflating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200345_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
#   inflating: src/UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200351_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
# ...

# %%
# !python3 main.py --lang urdu --mode train --phonetic true --freezing false
# Out:
# 2021-03-20 11:19:44.443116: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# tcmalloc: large alloc 2299912192 bytes == 0x55b59243c000 @  0x7f0c1119b001 0x7f0c0ec1954f 0x7f0c0ec69b58 0x7f0c0ec6db17 0x7f0c0ed0c203 0x55b57d125050 0x55b57d124de0 0x55b57d199244 0x55b57d12669a 0x55b57d198e50 0x55b57d12669a 0x55b57d194c9e 0x55b57d193e0d 0x55b57d12677a 0x55b57d194a45 0x55b57d193b0e 0x55b57d193813 0x55b57d25d592 0x55b57d25d90d 0x55b57d25d7b6 0x55b57d235103 0x55b57d234dac 0x7f0c0ff83bf7 0x55b57d234c8a
# 2021-03-20 11:20:27.879307: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 11:20:27.880223: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python3 main.py --lang urdu --mode test --phonetic true --freezing false
# Out:
# 2021-03-20 11:29:11.079096: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-20 11:29:16.970845: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 11:29:16.971816: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 11:29:17.002392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-20 11:29:17.003019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !python3 main.py --lang urdu --mode predict --phonetic true --freezing false
# Out:
# 2021-03-20 11:30:13.370903: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-20 11:30:15.750748: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 11:30:15.751694: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 11:30:15.782276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-20 11:30:15.782859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...
